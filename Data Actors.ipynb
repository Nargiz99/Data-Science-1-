# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
data = pd.read_excel("Data actors 1 - Copy.xlsx")

# %%
data
# Out:
#     Rank                                        Title  \
# 0      1                      Guardians of the Galaxy
# 1      2                                   Prometheus
# 2      3                                        Split
# 3      4                                         Sing
# 4      5                                Suicide Squad
# 5      6                               The Great Wall
# 6      7                                   La La Land
# 7      8                                     Mindhorn
# 8      9                           The Lost City of Z
# 9     10                                   Passengers
# 10    11      Fantastic Beasts and Where to Find Them
# 11    12                               Hidden Figures
# 12    13                                    Rogue One
# 13    14                                        Moana
# 14    15                                     Colossal
# 15    16                      The Secret Life of Pets
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director ', ' Actors ',
#        'Year', 'Runtime_Minutes', 'Rating', 'Votes', 'Revenue_Millions',
#        ' Metascore'],
#       dtype='object')

# %%
data.Revenue_Millions
# Out:
# 0     333.13
# 1     126.46
# 2     138.12
# 3        NaN
# 4     325.02
# 5      45.13
# 6        NaN
# 7        NaN
# 8       8.01
# 9     100.01
# 10    234.02
# 11       NaN
# 12    532.17
# 13    248.75
# 14       NaN
# 15    368.31
# 16       NaN
# 17    162.16
# 18     51.69
# 19    100.50
# 20      7.22
# 21     47.70
# 22       NaN
# 23    153.69
# 24    103.14
# 25       NaN
# 26      6.50
# 27      0.01
# 28    113.08
# 29     54.65
# 30       NaN
# 31     10.64
# 32       NaN
# 33    363.02
# 34     26.84
# 35    408.08
# 36    187.99
# 37       NaN
# 38     93.38
# 39       NaN
# 40     97.66
# 41     27.85
# 42       NaN
# 43     12.79
# 44      4.21
# 45    241.06
# 46      3.44
# 47       NaN
# 48    158.80
# 49       NaN
# 50    936.63
# 51     30.35
# 52     32.46
# 53     43.00
# 54    533.32
# 55      7.08
# 56     89.21
# Name: Revenue_Millions, dtype: float64

# %%
data.describe()
# Out:
#             Rank         Year  Runtime(Minutes)     Rating         Votes  \
# count  57.000000    44.000000         43.000000  51.000000  3.600000e+01
# mean   29.000000  2015.522727        117.325581   6.864706  2.285765e+05
# std    16.598193     1.810674         19.264723   1.167360  3.574549e+05
# min     1.000000  2007.000000         83.000000   2.700000  2.220000e+02
# 25%    15.000000  2016.000000        107.000000   6.300000  8.256000e+03
# 50%    29.000000  2016.000000        116.000000   7.100000  1.219780e+05
# 75%    43.000000  2016.000000        128.500000   7.550000  2.429315e+05
# max    57.000000  2016.000000        169.000000   9.000000  1.791916e+06
#
#        Revenue(Millions)   Metascore
# count          42.000000   42.000000
# mean          156.363810   63.690476
# std           189.636887   18.174611
# min             0.010000   16.000000
# 25%            28.475000   56.250000
# 50%            98.835000   65.500000
# 75%           222.512500   74.000000
# ...

# %%
data.describe(include='all')
# Out:
#              Rank   Title                     Genre  \
# count   57.000000      57                        52
# unique        NaN      57                        32
# top           NaN  Trolls  Action,Adventure,Fantasy
# freq          NaN       1                         6
# mean    29.000000     NaN                       NaN
# std     16.598193     NaN                       NaN
# min      1.000000     NaN                       NaN
# 25%     15.000000     NaN                       NaN
# 50%     29.000000     NaN                       NaN
# 75%     43.000000     NaN                       NaN
# max     57.000000     NaN                       NaN
#
#                                               Description          Director   \
# count                                                  57                 57
# unique                                                 57                 56
# top     A team of explorers travel through a wormhole ...  Christopher Nolan
# ...

# %%
data.describe(include='all').transpose()
# Out:
#                   count unique  \
# Rank                 57    NaN
# Title                57     57
# Genre                52     32
# Description          57     57
# Director             57     56
#  Actors              57     57
# Year                 44    NaN
# Runtime(Minutes)     43    NaN
# Rating               51    NaN
# Votes                36    NaN
# Revenue(Millions)    42    NaN
#  Metascore           42    NaN
#
#                                                                  top freq  \
# Rank                                                             NaN  NaN
# Title                                                         Trolls    1
# Genre                                       Action,Adventure,Fantasy    6
# Description        A team of explorers travel through a wormhole ...    1
# Director                                           Christopher Nolan    2
#  Actors            Amy Adams, Jake Gyllenhaal, Michael Shannon, A...    1
# ...

# %%
pd.read_excel("Data actors 1 - Copy.xlsx", header=None)
# Out:
#       0                                            1   \
# 0   Rank                                        Title
# 1      1                      Guardians of the Galaxy
# 2      2                                   Prometheus
# 3      3                                        Split
# 4      4                                         Sing
# 5      5                                Suicide Squad
# 6      6                               The Great Wall
# 7      7                                   La La Land
# 8      8                                     Mindhorn
# 9      9                           The Lost City of Z
# 10    10                                   Passengers
# 11    11      Fantastic Beasts and Where to Find Them
# 12    12                               Hidden Figures
# 13    13                                    Rogue One
# 14    14                                        Moana
# 15    15                                     Colossal
# ...

# %%
data["Genre"].fillna("Action,Adventure,Sci-Fi")
# Out:
# 0        Action,Adventure,Sci-Fi
# 1       Adventure,Mystery,Sci-Fi
# 2                Horror,Thriller
# 3        Animation,Comedy,Family
# 4       Action,Adventure,Fantasy
# 5       Action,Adventure,Fantasy
# 6             Comedy,Drama,Music
# 7                         Comedy
# 8     Action,Adventure,Biography
# 9        Adventure,Drama,Romance
# 10      Adventure,Family,Fantasy
# 11       Biography,Drama,History
# 12       Action,Adventure,Sci-Fi
# 13    Animation,Adventure,Comedy
# 14           Action,Comedy,Drama
# 15    Animation,Adventure,Comedy
# 16       Biography,Drama,History
# 17               Action,Thriller
# 18               Biography,Drama
# 19          Drama,Mystery,Sci-Fi
# 20      Adventure,Drama,Thriller
# 21                         Drama
# 22            Crime,Drama,Horror
# 23    Animation,Adventure,Comedy
# 24       Action,Adventure,Sci-Fi
# 25                        Comedy
# 26        Action,Adventure,Drama
# 27               Horror,Thriller
# ...

# %%
data.Genre.value_counts()
# Out:
# Action,Adventure,Fantasy      6
# Comedy                        4
# Drama                         4
# Animation,Adventure,Comedy    4
# Biography,Drama,History       3
# Action,Adventure,Drama        2
# Horror,Thriller               2
# Drama,Thriller                2
# Comedy,Drama                  2
# Comedy,Drama,Music            1
# Adventure,Family,Fantasy      1
# Action,Crime,Thriller         1
# Drama,Mystery,Sci-Fi          1
# Action,Horror,Sci-Fi          1
# Adventure,Drama,Thriller      1
# Crime,Horror,Thriller         1
# Action,Crime,Drama            1
# Adventure,Drama,History       1
# Horror                        1
# Action,Adventure,Biography    1
# Adventure,Drama,Sci-Fi        1
# Action,Thriller               1
# Action,Comedy,Drama           1
# Adventure,Drama,Romance       1
# Action,Adventure,Comedy       1
# Crime,Drama,Horror            1
# Adventure,Drama,Fantasy       1
# Animation,Comedy,Family       1
# Adventure,Mystery,Sci-Fi      1
# ...

# %%
data.fillna( method='ffill', limit = 2)
# Out:
#     Rank                                        Title  \
# 0      1                      Guardians of the Galaxy
# 1      2                                   Prometheus
# 2      3                                        Split
# 3      4                                         Sing
# 4      5                                Suicide Squad
# 5      6                               The Great Wall
# 6      7                                   La La Land
# 7      8                                     Mindhorn
# 8      9                           The Lost City of Z
# 9     10                                   Passengers
# 10    11      Fantastic Beasts and Where to Find Them
# 11    12                               Hidden Figures
# 12    13                                    Rogue One
# 13    14                                        Moana
# 14    15                                     Colossal
# 15    16                      The Secret Life of Pets
# ...

# %%
data[["Title", "Rating", "Revenue_Millions" ]].head(10)
# Out:
#                      Title  Rating  Revenue_Millions
# 0  Guardians of the Galaxy     8.1            333.13
# 1               Prometheus     7.0            126.46
# 2                    Split     7.3            138.12
# 3                     Sing     NaN               NaN
# 4            Suicide Squad     6.2            325.02
# 5           The Great Wall     NaN             45.13
# 6               La La Land     8.3               NaN
# 7                 Mindhorn     6.4               NaN
# 8       The Lost City of Z     7.1              8.01
# 9               Passengers     7.0            100.01

# %%
data["Title"][20:30]
# Out:
# 20                            Gold
# 21           Manchester by the Sea
# 22                  Hounds of Love
# 23                          Trolls
# 24    Independence Day: Resurgence
# 25                 Paris pieds nus
# 26         Bahubali: The Beginning
# 27                      Dead Awake
# 28                        Bad Moms
# 29                Assassin's Creed
# Name: Title, dtype: object

# %%
data[20:40:2]
# Out:
#     Rank                             Title                     Genre  \
# 20    21                              Gold  Adventure,Drama,Thriller
# 22    23                    Hounds of Love        Crime,Drama,Horror
# 24    25      Independence Day: Resurgence                       NaN
# 26    27           Bahubali: The Beginning    Action,Adventure,Drama
# 28    29                          Bad Moms                    Comedy
# 30    31                          Why Him?                    Comedy
# 32    33                 X-Men: Apocalypse   Action,Adventure,Sci-Fi
# 34    35  Resident Evil: The Final Chapter      Action,Horror,Sci-Fi
# 36    37                      Interstellar    Adventure,Drama,Sci-Fi
# 38    39             The Magnificent Seven  Action,Adventure,Western
#
#                                           Description           Director   \
# 20  Kenny Wells, a prospector desperate for a luck...      Stephen Gaghan
# ...

# %%
data[::-1]
# Out:
#     Rank                                        Title  \
# 56    57                                Don't Breathe
# 55    56                                      Silence
# 54    55                              The Dark Knight
# 53    54                                    John Wick
# 52    53                                 Mother's Day
# 51    52                       Underworld: Blood Wars
# 50    51   Star Wars: Episode VII - The Force Awakens
# 49    50                                The Last Face
# 48    49                             Star Trek Beyond
# 47    48                                       Fallen
# 46    47                                  Miss Sloane
# 45    46  Pirates of the Caribbean: On Stranger Tides
# 44    45                                    Lowriders
# 43    44                                  The Founder
# 42    43                      Don't Fuck in the Woods
# 41    42                                    Moonlight
# ...

# %%
data[["Title","Year"]][20:45]
# Out:
#                                Title    Year
# 20                              Gold  2016.0
# 21             Manchester by the Sea  2016.0
# 22                    Hounds of Love     NaN
# 23                            Trolls  2016.0
# 24      Independence Day: Resurgence  2016.0
# 25                   Paris pieds nus  2016.0
# 26           Bahubali: The Beginning  2015.0
# 27                        Dead Awake  2016.0
# 28                          Bad Moms  2016.0
# 29                  Assassin's Creed  2016.0
# 30                          Why Him?  2016.0
# 31                 Nocturnal Animals  2016.0
# 32                 X-Men: Apocalypse     NaN
# 33                          Deadpool  2016.0
# 34  Resident Evil: The Final Chapter  2016.0
# 35        Captain America: Civil War  2016.0
# 36                      Interstellar     NaN
# 37                    Doctor Strange  2016.0
# 38             The Magnificent Seven  2016.0
# 39                         5- 25- 77  2007.0
# ...

# %%
data["Votes"] / data.Rating
# Out:
# 0      93465.925926
# 1      69402.857143
# 2               NaN
# 3               NaN
# 4      63504.354839
# 5               NaN
# 6               NaN
# 7        389.062500
# 8       1012.394366
# 9               NaN
# 10     30942.933333
# 11     11936.282051
# 12              NaN
# 13     15344.285714
# 14              NaN
# 15              NaN
# 16              NaN
# 17     22510.895522
# 18              NaN
# 19     42599.750000
# 20              NaN
# 21     16988.987342
# 22       166.417910
# 23              NaN
# 24     24066.603774
# 25        32.647059
# 26      9179.879518
# 27       111.276596
# 28              NaN
# 29     19120.847458
# 30              NaN
# 31     16804.000000
# 32     38804.225352
# 33              NaN
# 34      8243.750000
# 35              NaN
# 36    121831.046512
# 37              NaN
# 38     17804.782609
# 39        33.943662
# 40              NaN
# 41     18012.666667
# 42       183.703704
# 43              NaN
# 44        44.285714
# ...

# %%
data["Revenue_Millions"] / data.Votes
# Out:
# 0     0.000440
# 1     0.000260
# 2          NaN
# 3          NaN
# 4     0.000825
# 5          NaN
# 6          NaN
# 7          NaN
# 8     0.001114
# 9          NaN
# 10    0.001008
# 11         NaN
# 12         NaN
# 13    0.002105
# 14         NaN
# 15         NaN
# 16         NaN
# 17    0.001075
# 18         NaN
# 19    0.000295
# 20         NaN
# 21    0.000355
# 22         NaN
# 23         NaN
# 24    0.000809
# 25         NaN
# 26    0.000085
# 27    0.000019
# 28         NaN
# 29    0.000484
# 30         NaN
# 31    0.000084
# 32         NaN
# 33         NaN
# 34    0.000581
# 35         NaN
# 36    0.000179
# 37         NaN
# 38    0.000760
# 39         NaN
# 40         NaN
# 41    0.000206
# 42         NaN
# 43         NaN
# 44    0.015090
# 45    0.000610
# 46         NaN
# 47         NaN
# 48    0.000965
# 49         NaN
# 50    0.001416
# 51         NaN
# 52    0.001605
# 53         NaN
# 54    0.000298
# 55         NaN
# 56    0.000737
# dtype: float64

# %%
result = data.Revenue_Millions - data["Votes"]

# %%
result
# Out:
# 0     -756740.87
# 1     -485693.54
# 2            NaN
# 3            NaN
# 4     -393401.98
# 5            NaN
# 6            NaN
# 7            NaN
# 8       -7179.99
# 9            NaN
# 10    -231837.98
# 11           NaN
# 12           NaN
# 13    -117902.25
# 14           NaN
# 15           NaN
# 16           NaN
# 17    -150660.84
# 18           NaN
# 19    -340697.50
# 20           NaN
# 21    -134165.30
# 22           NaN
# 23           NaN
# 24    -127449.86
# 25           NaN
# 26     -76186.50
# 27       -522.99
# 28           NaN
# 29    -112758.35
# 30           NaN
# 31    -126019.36
# 32           NaN
# 33           NaN
# 34     -46138.16
# 35           NaN
# 36   -1047559.01
# 37           NaN
# 38    -122759.62
# 39           NaN
# 40           NaN
# 41    -135067.15
# 42           NaN
# 43           NaN
# 44       -274.79
# 45    -394783.94
# 46           NaN
# 47           NaN
# 48    -164408.20
# 49           NaN
# 50    -660671.37
# 51           NaN
# ...

# %%
data.Rating[10:20] < 7.5
# Out:
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17     True
# 18    False
# 19    False
# Name: Rating, dtype: bool

# %%
data.Rating[10:20][data.Rating[10:20] > 7.5]
# Out:
# 11    7.8
# 13    7.7
# 18    8.1
# 19    8.0
# Name: Rating, dtype: float64

# %%
filterr1 = data.Rating > 7.5

# %%
filterr1
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35    False
# 36     True
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50     True
# 51    False
# 52    False
# 53    False
# 54     True
# 55    False
# 56    False
# Name: Rating, dtype: bool

# %%
len(data[filterr1])
# Out:
# 13

# %%
filterr2 = data.Revenue_Millions > 8.55

# %%
filterr2
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12     True
# 13     True
# 14    False
# 15     True
# 16    False
# 17     True
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28     True
# 29     True
# 30    False
# 31     True
# 32    False
# 33     True
# 34     True
# 35     True
# 36     True
# 37    False
# 38     True
# 39    False
# 40     True
# 41     True
# 42    False
# 43     True
# 44    False
# 45     True
# 46    False
# 47    False
# 48     True
# 49    False
# 50     True
# 51     True
# 52     True
# 53     True
# 54     True
# 55    False
# 56     True
# Name: Revenue_Millions, dtype: bool

# %%
(data.Rating > 7.5) & (data.Revenue_Millions > 8.55)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50     True
# 51    False
# 52    False
# 53    False
# 54     True
# 55    False
# 56    False
# dtype: bool

# %%
data[(data.Rating > 7.5) & (data.Revenue_Millions > 8.55)]
# Out:
#     Rank                                       Title  \
# 0      1                     Guardians of the Galaxy
# 13    14                                       Moana
# 18    19                                        Lion
# 19    20                                     Arrival
# 21    22                       Manchester by the Sea
# 33    34                                    Deadpool
# 36    37                                Interstellar
# 50    51  Star Wars: Episode VII - The Force Awakens
# 54    55                             The Dark Knight
#
#                          Genre  \
# 0                          NaN
# 13  Animation,Adventure,Comedy
# 18             Biography,Drama
# 19        Drama,Mystery,Sci-Fi
# 21                       Drama
# 33     Action,Adventure,Comedy
# 36      Adventure,Drama,Sci-Fi
# 50    Action,Adventure,Fantasy
# 54          Action,Crime,Drama
#
#                                           Description          Director   \
# ...

# %%
sub10 = data[::10]

# %%
sub10
# Out:
#     Rank                                       Title  \
# 0      1                     Guardians of the Galaxy
# 10    11     Fantastic Beasts and Where to Find Them
# 20    21                                        Gold
# 30    31                                    Why Him?
# 40    41                               Sausage Party
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                          Genre  \
# 0                          NaN
# 10    Adventure,Family,Fantasy
# 20    Adventure,Drama,Thriller
# 30                      Comedy
# 40  Animation,Adventure,Comedy
# 50    Action,Adventure,Fantasy
#
#                                           Description       Director   \
# 0   A group of intergalactic criminals are forced ...      James Gunn
# 10  The adventures of writer Newt Scamander in New...     David Yates
# 20  Kenny Wells, a prospector desperate for a luck...  Stephen Gaghan
# 30  A holiday gathering threatens to go off the ra...    John Hamburg
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = 12 , 4

# %%
visl = sns.distplot(data['Rating'], bins=10, color = "red" )

# %%
visl2 = sns.lmplot(data=data, x = "Rating", y = 'Revenue_Millions')
